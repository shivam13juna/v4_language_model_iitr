# %% [markdown]
# Imagine you run an e-commerce platform with 10,000 products. Each product needs an SEO summary and feature extraction. At \$0.15/1M input tokens (gpt-4o-mini), a naive loop sends the same massive system prompt 10,000 times — paying full price every time. And each call blocks until the previous one finishes.

# %% [markdown]
# You are an assistant that summarizes products for SEO and extracts key features. Return JSON with
# the keys, summary, and the features.

# %%
# !pip install openai python-dotenv pandas
import pandas as pd
import os, json, time
from dotenv import load_dotenv
from openai import OpenAI
import textwrap

import truststore
truststore.inject_into_ssl()



def pretty_print(*args):
    text = " ".join(str(arg) for arg in args)
    try:
        print(textwrap.fill(text, width=80))
    except Exception as e:
        print(text)  # fallback to normal print if text is not a string

        

load_dotenv('/Users/shivam13juna/Documents/scaler/GEN_AI_REF/openai_key.env')

api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError(
        "OPENAI_API_KEY not found! "
        "Make sure you have a .env file with: OPENAI_API_KEY=sk-..."
    )

pretty_print("API key loaded successfully.")

MODEL = 'gpt-5-nano'




client = OpenAI(api_key=api_key)
pretty_print("OpenAI client ready.")
# Out:
# API key loaded successfully.
# OpenAI client ready.

# %%
products = [
    {"id": "P001", "name": "Wireless Bluetooth Headphones", "description": "Over-ear wireless headphones with active noise cancellation, 30-hour battery life, and foldable design. Features Bluetooth 5.3 and multipoint connectivity."},
    {"id": "P002", "name": "Ergonomic Office Chair", "description": "Adjustable lumbar support office chair with breathable mesh back, 4D armrests, seat depth adjustment, and 135-degree recline. Supports up to 300 lbs."},
    {"id": "P003", "name": "Stainless Steel Water Bottle", "description": "Double-wall vacuum insulated 1-liter water bottle. Keeps drinks cold 24 hours or hot 12 hours. BPA-free, leak-proof lid with carrying loop."},
    {"id": "P004", "name": "Mechanical Keyboard", "description": "Compact 75% layout mechanical keyboard with hot-swappable switches, RGB backlighting, gasket mount structure, and PBT double-shot keycaps. USB-C and wireless."},
    {"id": "P005", "name": "Portable Power Station", "description": "500Wh portable power station with LiFePO4 battery, 800W pure sine wave AC output, 100W USB-C PD charging, and solar panel input. Weighs 14 lbs."},
    {"id": "P006", "name": "Smart Doorbell Camera", "description": "2K HDR video doorbell with 180-degree field of view, two-way audio, night vision, and local storage via microSD. Works with Alexa and Google Home."},
    {"id": "P007", "name": "Air Purifier", "description": "HEPA 13 air purifier covering 1,200 sq ft. Auto mode with air quality sensor, whisper-quiet 24dB sleep mode, and filter replacement indicator."},
    {"id": "P008", "name": "Camping Hammock", "description": "Ultralight double camping hammock made from 70D ripstop nylon. Holds 500 lbs. Includes tree straps, carabiners, and stuff sack. Packs down to 1 lb."},
    {"id": "P009", "name": "Electric Standing Desk", "description": "Dual-motor electric standing desk with 60x30 inch bamboo top. Height range 25.6-51.2 inches, 4 memory presets, cable management tray, and anti-collision sensor."},
    {"id": "P010", "name": "Robot Vacuum Cleaner", "description": "LiDAR navigation robot vacuum with 5000Pa suction, auto-empty dock, mop attachment, no-go zones via app, and 180-minute runtime on hardwood and carpet."}
]

df = pd.DataFrame(products)
df
# Out:
#      id                           name  \
# 0  P001  Wireless Bluetooth Headphones
# 1  P002         Ergonomic Office Chair
# 2  P003   Stainless Steel Water Bottle
# 3  P004            Mechanical Keyboard
# 4  P005         Portable Power Station
# 5  P006          Smart Doorbell Camera
# 6  P007                   Air Purifier
# 7  P008                Camping Hammock
# 8  P009         Electric Standing Desk
# 9  P010           Robot Vacuum Cleaner
#
#                                          description
# 0  Over-ear wireless headphones with active noise...
# 1  Adjustable lumbar support office chair with br...
# 2  Double-wall vacuum insulated 1-liter water bot...
# 3  Compact 75% layout mechanical keyboard with ho...
# 4  500Wh portable power station with LiFePO4 batt...
# 5  2K HDR video doorbell with 180-degree field of...
# 6  HEPA 13 air purifier covering 1,200 sq ft. Aut...
# 7  Ultralight double camping hammock made from 70...
# 8  Dual-motor electric standing desk with 60x30 i...
# 9  LiDAR navigation robot vacuum with 5000Pa suct...

# %%
# A short, simple system prompt — well under 1024 tokens
short_prompt = "You are an assistant that summarizes products for SEO and extracts key features. Return JSON with keys: summary (2 sentences) and features (list of 3-5 strings)."

# %%
naive_results = []

for product in products[:5]:  # start with 5 products
    start = time.time()
    
    response = client.responses.create(
        model=MODEL,
        instructions=short_prompt,
        input=f"Product: {product['name']}\nDescription: {product['description']}"
    )
    
    elapsed = time.time() - start
    
    usage = response.usage
    cached = usage.input_tokens_details.cached_tokens if usage.input_tokens_details else 0
    
    naive_results.append({
        "product": product["name"],
        "input_tokens": usage.input_tokens,
        "output_tokens": usage.output_tokens,
        "cached_tokens": cached,
        "latency_s": round(elapsed, 2),
        "output_preview": response.output_text[:120] + "..."
    })
    
    print(f"✅ {product['name']}: {elapsed:.2f}s | input={usage.input_tokens} | cached={cached} | output={usage.output_tokens}")

print(f"\n⏱️  Total time: {sum(r['latency_s'] for r in naive_results):.2f}s")
# Out:
# ✅ Wireless Bluetooth Headphones: 9.61s | input=85 | cached=0 | output=916
# ✅ Ergonomic Office Chair: 8.66s | input=88 | cached=0 | output=931
# ✅ Stainless Steel Water Bottle: 5.47s | input=86 | cached=0 | output=531
# ✅ Mechanical Keyboard: 26.31s | input=86 | cached=0 | output=2399
# ✅ Portable Power Station: 7.96s | input=95 | cached=0 | output=1187
#
# ⏱️  Total time: 58.01s

# %%
long_system_prompt = """
You are an expert e-commerce product content specialist working for a major online marketplace.
Your job is to create SEO-optimized product summaries and extract structured feature data.

=== OUTPUT FORMAT ===
You MUST respond with valid JSON only. No markdown, no explanation, just the JSON object.
{
  "seo_summary": "A compelling 2-3 sentence summary optimized for search engines. Include the product name, primary benefit, and a call-to-action phrase. Use active voice throughout.",
  "features": ["Feature 1 as a concise bullet point", "Feature 2", ...],
  "category": "The most specific product category",
  "target_audience": "Who this product is best suited for",
  "keywords": ["seo", "keyword", "list"]
}

=== WRITING STYLE GUIDE ===
1. Always write in active voice. BAD: "The battery is designed to last 30 hours." GOOD: "Enjoy 30 hours of uninterrupted battery life."
2. Lead with the primary benefit, not the feature. BAD: "Has Bluetooth 5.3" GOOD: "Connect seamlessly to all your devices with Bluetooth 5.3"
3. Use power words: discover, transform, elevate, essential, premium, revolutionary, seamless
4. Avoid superlatives without evidence. Don't say "best" or "greatest" unless the product description provides comparative data.
5. Keep sentences between 15-25 words for readability.
6. Include at least one emotional trigger word per summary (comfort, confidence, peace of mind, freedom, etc.)
7. End the SEO summary with an implicit call-to-action ("Upgrade your...", "Transform your...", "Experience...")

=== FEATURE EXTRACTION RULES ===
1. Extract 3-5 features maximum. Prioritize by consumer impact.
2. Each feature should be a standalone phrase (not a full sentence). 5-12 words each.
3. Always include the primary spec (battery life, weight, capacity, etc.) with units.
4. Group related specs into a single feature when possible.
5. Order features from most important to least important for the target consumer.

=== CATEGORY TAXONOMY ===
Use the most specific category from this hierarchy:
- Electronics > Audio > Headphones > Over-Ear / In-Ear / On-Ear
- Electronics > Computers > Peripherals > Keyboards / Mice / Monitors
- Electronics > Smart Home > Security / Lighting / Climate / Cleaning
- Furniture > Office > Chairs / Desks / Storage
- Outdoor & Sports > Camping > Shelter / Sleep / Cook / Accessories
- Kitchen & Home > Drinkware / Cookware / Appliances
- Power & Energy > Portable Power / Solar / Batteries

=== KEYWORD GUIDELINES ===
1. Generate 5-8 SEO keywords per product.
2. Include both short-tail (1-2 words) and long-tail (3-5 words) keywords.
3. Always include the product type, primary feature, and target use case.
4. Avoid brand names unless provided in the product description.
5. Include common misspellings or alternative terms consumers might search for.

=== FEW-SHOT EXAMPLES ===

EXAMPLE INPUT:
Product: Running Shoes
Description: Lightweight mesh running shoes with responsive foam cushioning, reinforced heel counter, and reflective details. Available in sizes 6-14. Weighs 8.5 oz.

EXAMPLE OUTPUT:
{
  "seo_summary": "Hit the pavement with confidence in these ultralight running shoes featuring responsive foam cushioning that absorbs impact mile after mile. The breathable mesh upper and reinforced heel deliver the perfect balance of comfort and stability. Elevate your running experience today.",
  "features": ["Responsive foam cushioning for impact absorption", "Breathable lightweight mesh upper at 8.5 oz", "Reinforced heel counter for stability", "Reflective details for low-light visibility", "Available in sizes 6 through 14"],
  "category": "Outdoor & Sports > Running > Footwear",
  "target_audience": "Recreational and intermediate runners seeking lightweight, cushioned footwear",
  "keywords": ["running shoes", "lightweight running shoes", "cushioned running shoes", "mesh running shoes", "reflective running shoes", "responsive foam shoes", "8.5 oz running shoes"]
}

EXAMPLE INPUT:
Product: Yoga Mat
Description: 6mm thick non-slip yoga mat made from natural tree rubber with alignment markings. Dimensions 72x26 inches. Includes carrying strap. Free from PVC, latex, and silicone.

EXAMPLE OUTPUT:
{
  "seo_summary": "Transform your practice on this premium natural rubber yoga mat with built-in alignment markings that guide your poses with precision. The 6mm thick non-slip surface provides the perfect cushion-to-grip ratio for any flow style. Discover your best practice with this eco-friendly essential.",
  "features": ["6mm natural tree rubber with non-slip grip", "Built-in alignment markings for guided practice", "72x26 inch full-size dimensions", "Eco-friendly: PVC, latex, and silicone free", "Includes carrying strap for portability"],
  "category": "Outdoor & Sports > Yoga > Mats",
  "target_audience": "Yoga practitioners of all levels seeking an eco-conscious, non-slip mat",
  "keywords": ["yoga mat", "non-slip yoga mat", "natural rubber yoga mat", "alignment yoga mat", "eco-friendly yoga mat", "6mm yoga mat", "yoga mat with markings"]
}

=== IMPORTANT REMINDERS ===
- Output ONLY the JSON object. No preamble, no markdown code fences, no explanation.
- If the product description is vague, make reasonable inferences but do not fabricate specific numbers.
- Use American English spelling throughout.
- Ensure all JSON keys are exactly as shown in the format specification above.
"""

# Rough token count check (1 token ≈ 4 chars for English)
estimated_tokens = len(long_system_prompt) / 4
print(f"Estimated system prompt tokens: ~{int(estimated_tokens)}")
print(f"Meets 1024-token minimum: {'✅ Yes' if estimated_tokens >= 1024 else '❌ No — need to expand'}")
# Out:
# Estimated system prompt tokens: ~1344
# Meets 1024-token minimum: ✅ Yes

# %%
cache_results = []

for i, product in enumerate(products[:5]):
    start = time.time()
    
    response = client.responses.create(
        model=MODEL,
        instructions=long_system_prompt,
        input=f"Product: {product['name']}\nDescription: {product['description']}"
    )
    
    elapsed = time.time() - start
    usage = response.usage
    cached = usage.input_tokens_details.cached_tokens if usage.input_tokens_details else 0
    
    cache_results.append({
        "request_num": i + 1,
        "product": product["name"],
        "input_tokens": usage.input_tokens,
        "cached_tokens": cached,
        "cache_hit_pct": f"{(cached / usage.input_tokens * 100):.1f}%" if usage.input_tokens > 0 else "0%",
        "output_tokens": usage.output_tokens,
        "latency_s": round(elapsed, 2)
    })
    
    print(f"Request {i+1}: {product['name'][:30]:30s} | latency={elapsed:.2f}s | cached={cached}/{usage.input_tokens} tokens")

print(f"\n⏱️  Total: {sum(r['latency_s'] for r in cache_results):.2f}s")
# Out:
# Request 1: Wireless Bluetooth Headphones  | latency=21.23s | cached=0/1249 tokens
# Request 2: Ergonomic Office Chair         | latency=18.61s | cached=1152/1252 tokens
# Request 3: Stainless Steel Water Bottle   | latency=14.67s | cached=0/1250 tokens
# Request 4: Mechanical Keyboard            | latency=21.24s | cached=0/1250 tokens
# Request 5: Portable Power Station         | latency=21.30s | cached=1152/1259 tokens
#
# ⏱️  Total: 97.05s

# %%
INPUT_COST_PER_M = 0.05
CACHED_COST_PER_M = 0.005
OUTPUT_COST_PER_M = 0.40


def calculate_cost_from_averages(
    num_requests,
    avg_input_tokens,
    avg_cached_tokens,
    avg_output_tokens,
):
    if avg_cached_tokens > avg_input_tokens:
        raise ValueError("avg_cached_tokens cannot exceed avg_input_tokens")

    total_input = num_requests * avg_input_tokens
    total_cached = num_requests * avg_cached_tokens
    total_uncached = total_input - total_cached
    total_output = num_requests * avg_output_tokens

    input_cost = (
        (total_uncached / 1_000_000) * INPUT_COST_PER_M
        + (total_cached / 1_000_000) * CACHED_COST_PER_M
    )
    output_cost = (total_output / 1_000_000) * OUTPUT_COST_PER_M
    total_cost = input_cost + output_cost

    return {
        "num_requests": num_requests,
        "total_input_tokens": total_input,
        "cached_tokens": total_cached,
        "uncached_tokens": total_uncached,
        "output_tokens": total_output,
        "input_cost": input_cost,
        "output_cost": output_cost,
        "total_cost": total_cost,
    }


def compare_scenarios(num_requests, naive, cached):
    naive_cost = calculate_cost_from_averages(num_requests, **naive)
    cached_cost = calculate_cost_from_averages(num_requests, **cached)

    savings = naive_cost["total_cost"] - cached_cost["total_cost"]
    savings_pct = (savings / naive_cost["total_cost"]) * 100 if naive_cost["total_cost"] else 0

    return naive_cost, cached_cost, savings, savings_pct


NUM_REQUESTS = 1_000_000

naive_profile = {
    "avg_input_tokens": 4000,
    "avg_cached_tokens": 0,
    "avg_output_tokens": 100,
}

cached_profile = {
    "avg_input_tokens": 4000,
    "avg_cached_tokens": 3500,
    "avg_output_tokens": 100,
}

naive_cost, cached_cost, savings, savings_pct = compare_scenarios(
    NUM_REQUESTS,
    naive_profile,
    cached_profile,
)

print("Naive total cost:  $%.2f" % naive_cost["total_cost"])
print("Cached total cost: $%.2f" % cached_cost["total_cost"])
print("Savings:           $%.2f (%.2f%%)" % (savings, savings_pct))
# Out:
# Naive total cost:  $240.00
# Cached total cost: $82.50
# Savings:           $157.50 (65.62%)

# %%
response = client.responses.create(
    model=MODEL,
    instructions='translate given text to french',
    input=f"Product: {product['name']}\nDescription: {product['description']}"
)

# %%
net_text = MODEL + " " + 'translate given text to french' + " " + f"Product: {product['name']}\nDescription: {product['description']}"
net_text
# Out:
# 'gpt-5-nano translate given text to french Product: Portable Power Station\nDescription: 500Wh portable power station with LiFePO4 battery, 800W pure sine wave AC output, 100W USB-C PD charging, and solar panel input. Weighs 14 lbs.'

# %%
hash(net_text)
# Out:
# 8498327598655081966

# %% [markdown]
# # Batching API

# %% [markdown]
# ```
# ┌─────────────────┐     ┌──────────────┐     ┌──────────────┐
# │  Prepare JSONL   │────▶│  Upload file  │────▶│ Create batch  │
# │  (local)         │     │  (Files API)  │     │ (Batches API) │
# └─────────────────┘     └──────────────┘     └──────┬───────┘
#                                                      │
#                                                      ▼
#                          ┌──────────────┐     ┌──────────────┐
#                          │ Download file │◀────│ Poll status   │
#                          │ (Files API)   │     │ until done    │
#                          └──────────────┘     └──────────────┘
# ```

# %% [markdown]
# What if you have 10,000 products to process and don't need results instantly? The **Batch API** lets you:
#
# 1. Bundle thousands of requests into a single **JSONL file**
# 2. Upload and submit them as one **batch job**
# 3. Poll until done (up to 24 hours, usually much faster)
# 4. Download all results at once
#
# The reward? **50% cost discount** and **separate rate limits** that won't throttle your live traffic.

# %% [markdown]
# Some real-life cases where Batch API makes sense:
#
# **1. Support-ticket triage at the end of the hour/day.**
# A company dumps thousands of Zendesk or email tickets into a batch job to classify intent, urgency, language, likely team, and maybe draft a suggested reply. This fits Batch because it is built for **asynchronous jobs**, offers **50% lower costs**, and is meant for workloads that **do not require immediate responses**. ([OpenAI Developers][1])
#
# **2. E-commerce catalog enrichment.**
# Marketplaces use it to generate product titles, bullet summaries, attribute extraction, taxonomy tags, or image captions across large catalogs. OpenAI’s cookbook explicitly calls out **tagging, captioning, or enriching content on a marketplace or blog** as a Batch-style workload. ([OpenAI Developers][2])
#
# **3. Large-scale document summarization or translation.**
# If you have a backlog of articles, PDFs, legal docs, or internal reports and want summaries, translations, or structured extraction overnight, Batch is a good fit. The cookbook lists **summaries or translations for collections of documents or articles** as a core example. ([OpenAI Developers][2])
#
# **4. Customer-feedback analytics.**
# Teams often run daily or weekly jobs over NPS comments, app-store reviews, survey free text, and call transcripts to do sentiment analysis, topic clustering, complaint extraction, and trend reporting. The cookbook specifically mentions **sentiment analysis on large datasets of customer feedback**. ([OpenAI Developers][2])
#
# **5. Offline moderation and safety sweeps.**
# A platform can scan a backlog of posts, comments, images, or uploads for policy violations instead of scoring every item live. Batch is useful when you want higher throughput and lower cost, and you can tolerate the documented **24-hour completion window**. ([OpenAI Developers][1])
#
# **6. Eval pipelines and regression testing.**
# Model teams use Batch to run the same prompt set over thousands of test cases after changing prompts, tools, or model versions. This is one of the classic “not user-facing, high-volume” jobs, and Batch supports large JSONL input files with up to **50,000 requests per file**. ([OpenAI Platform][3])
#
# **7. CRM / lead enrichment.**
# Sales and ops teams can process lead records in bulk to normalize company descriptions, classify industry, summarize account notes, or extract fields from messy text. This is basically the same pattern as data enrichment workloads that the docs position for Batch and related lower-cost async processing. ([OpenAI Developers][1])
#
# **8. Backfill jobs after launching a new feature.**
# Example: you add “AI summaries” to your app and need to generate summaries for the last 2 million old records. Batch is ideal for this kind of one-time backlog processing because it uses a **separate pool of significantly higher rate limits** than normal synchronous traffic. ([OpenAI Developers][1])
#
# Where Batch is usually **not** the right tool: live chat, autocomplete, agent loops, or anything user-facing where waiting minutes or hours is unacceptable. The official guide is explicit that it is for jobs that **don’t require immediate responses** and uses a **24-hour turnaround window**. ([OpenAI Developers][1])
#
# A simple rule: we use Batch when the work is **high-volume, offline, and delay-tolerant**. Use regular synchronous APIs when a human is waiting.
#
# [1]: https://developers.openai.com/api/docs/guides/batch/?utm_source=chatgpt.com "Batch API"
# [2]: https://developers.openai.com/cookbook/examples/batch_processing/?utm_source=chatgpt.com "Batch processing with the Batch API"
# [3]: https://platform.openai.com/docs/api-reference/batch?_clear=true&lang=node&utm_source=chatgpt.com "Batch | OpenAI API Reference"

# %% [markdown]
# **JSON** is one structured value.
# **JSONL** is many JSON values, one per line.
#
#
# 1. Example 1
#
#
# Example JSON:
#
# ```json
# {
#   "users": [
#     { "id": 1, "name": "A" },
#     { "id": 2, "name": "B" }
#   ]
# }
# ```
#
# Example JSONL:
#
# ```json
# {"id": 1, "name": "A"}
# {"id": 2, "name": "B"}
# ```
#
#
# 2. Exmple 2
#
# One whole document:
#
# ```json
# {
#   "orders": [
#     {
#       "order_id": "A1001",
#       "customer": "Shivam",
#       "amount": 499,
#       "status": "paid"
#     },
#     {
#       "order_id": "A1002",
#       "customer": "Riya",
#       "amount": 899,
#       "status": "pending"
#     },
#     {
#       "order_id": "A1003",
#       "customer": "Arjun",
#       "amount": 1299,
#       "status": "shipped"
#     }
#   ]
# }
# ```
#
# ---
#
#
# One record per line:
#
# ```json
# {"order_id":"A1001","customer":"Shivam","amount":499,"status":"paid"}
# {"order_id":"A1002","customer":"Riya","amount":899,"status":"pending"}
# {"order_id":"A1003","customer":"Arjun","amount":1299,"status":"shipped"}
# ```
#
# 3. Example 3
#
# ```json
# [
#   {"event":"login","user":"u1"},
#   {"event":"search","user":"u2"},
#   {"event":"logout","user":"u1"}
# ]
# ```
#
# Adding one more record means editing the array structure carefully.
#
# With JSONL, you just append another line:
#
# ```json
# {"event":"login","user":"u1"}
# {"event":"search","user":"u2"}
# {"event":"logout","user":"u1"}
# {"event":"purchase","user":"u3"}
# ```

# %%
batch_requests = []

for product in products:
    request = {
        "custom_id": f"product-{product['id']}",
        "method": "POST",
        "url": "/v1/responses",
        "body": {
            "model": MODEL,
            "instructions": long_system_prompt,
            "input": f"Product: {product['name']}\nDescription: {product['description']}"
        }
    }
    batch_requests.append(request)

# Write to JSONL file
batch_file_path = "batch_input.jsonl"
with open(batch_file_path, "w") as f:
    for req in batch_requests:
        f.write(json.dumps(req) + "\n")

print(f"Created {batch_file_path} with {len(batch_requests)} requests")
print(f"File size: {os.path.getsize(batch_file_path):,} bytes")
# Out:
# Created batch_input.jsonl with 10 requests
# File size: 59,140 bytes

# %%
# Let's peek at what one line looks like
with open(batch_file_path) as f:
    first_line = json.loads(f.readline())

# Show structure (truncate the long prompt for readability)
preview = first_line.copy()
preview["body"] = {**preview["body"], "instructions": preview["body"]["instructions"][:100] + "..."}
print(json.dumps(preview, indent=2))
# Out:
# {
#   "custom_id": "product-P001",
#   "method": "POST",
#   "url": "/v1/responses",
#   "body": {
#     "model": "gpt-5-nano",
#     "instructions": "\nYou are an expert e-commerce product content specialist working for a major online marketplace.\nYou...",
#     "input": "Product: Wireless Bluetooth Headphones\nDescription: Over-ear wireless headphones with active noise cancellation, 30-hour battery life, and foldable design. Features Bluetooth 5.3 and multipoint connectivity."
#   }
# }

# %%
# Upload the JSONL file
batch_file = client.files.create(
    file=open(batch_file_path, "rb"),
    purpose="batch"
)
print(f"Uploaded file: {batch_file.id}")
print(f"Status: {batch_file.status}")
# Out:
# Uploaded file: file-NWTcc5hrEV8vknSMDmMDQ4
# Status: processed

# %%
# Create the batch job
batch_job = client.batches.create(
    input_file_id=batch_file.id,
    endpoint="/v1/responses",
    completion_window="24h",
    metadata={
        "description": "Product enrichment demo — 10 products"
    }
)

print(f"Batch ID: {batch_job.id}")
print(f"Status: {batch_job.status}")
print(f"Created at: {batch_job.created_at}")
# Out:
# Batch ID: batch_6aa03405a098819099d45bd670f11454
# Status: validating
# Created at: 1788883973

# %%
poll_start = time.time()

while True:
    job = client.batches.retrieve(batch_job.id)
    elapsed = time.time() - poll_start
    
    completed = job.request_counts.completed if job.request_counts else 0
    total = job.request_counts.total if job.request_counts else 0
    
    print(f"[{elapsed:6.1f}s] Status: {job.status:15s} | Progress: {completed}/{total}")
    
    if job.status in ["completed", "failed", "expired", "cancelled"]:
        break
    
    time.sleep(10)

print(f"\n✅ Batch finished in {elapsed:.1f}s with status: {job.status}")
if job.request_counts:
    print(f"   Completed: {job.request_counts.completed} | Failed: {job.request_counts.failed}")
# Out:
# [   0.5s] Status: in_progress     | Progress: 0/10
# [  10.9s] Status: in_progress     | Progress: 0/10
# [  21.3s] Status: in_progress     | Progress: 0/10
# [  31.8s] Status: in_progress     | Progress: 0/10
# [  42.9s] Status: in_progress     | Progress: 0/10
# [  53.5s] Status: in_progress     | Progress: 0/10
# [  64.0s] Status: in_progress     | Progress: 0/10
# [  74.4s] Status: in_progress     | Progress: 0/10
# [  84.9s] Status: in_progress     | Progress: 0/10
# [  95.4s] Status: in_progress     | Progress: 0/10
# [ 105.9s] Status: in_progress     | Progress: 0/10
# [ 116.3s] Status: in_progress     | Progress: 0/10
# [ 126.7s] Status: in_progress     | Progress: 0/10
# [ 137.2s] Status: in_progress     | Progress: 0/10
# [ 147.7s] Status: in_progress     | Progress: 0/10
# [ 158.3s] Status: in_progress     | Progress: 0/10
# [ 168.8s] Status: in_progress     | Progress: 0/10
# [ 179.3s] Status: in_progress     | Progress: 0/10
# [ 189.8s] Status: in_progress     | Progress: 0/10
# [ 200.3s] Status: in_progress     | Progress: 0/10
# [ 217.6s] Status: in_progress     | Progress: 0/10
# [ 228.0s] Status: in_progress     | Progress: 0/10
# [ 238.6s] Status: in_progress     | Progress: 0/10
# [ 249.1s] Status: in_progress     | Progress: 0/10
# [ 259.7s] Status: in_progress     | Progress: 0/10
# [ 270.3s] Status: in_progress     | Progress: 0/10
# [ 280.8s] Status: in_progress     | Progress: 0/10
# [ 291.3s] Status: in_progress     | Progress: 0/10
# [ 301.8s] Status: in_progress     | Progress: 0/10
# [ 312.4s] Status: in_progress     | Progress: 0/10
# [ 322.9s] Status: in_progress     | Progress: 0/10
# [ 333.4s] Status: in_progress     | Progress: 0/10
# [ 343.8s] Status: in_progress     | Progress: 0/10
# [ 354.2s] Status: in_progress     | Progress: 0/10
# [ 364.7s] Status: in_progress     | Progress: 0/10
# [ 375.2s] Status: in_progress     | Progress: 0/10
# [ 385.7s] Status: in_progress     | Progress: 0/10
# [ 396.2s] Status: in_progress     | Progress: 0/10
# [ 406.6s] Status: in_progress     | Progress: 0/10
# [ 417.1s] Status: in_progress     | Progress: 0/10
# [ 427.6s] Status: in_progress     | Progress: 0/10
# [ 438.3s] Status: in_progress     | Progress: 0/10
# [ 448.8s] Status: in_progress     | Progress: 0/10
# [ 461.9s] Status: in_progress     | Progress: 0/10
# [ 472.5s] Status: in_progress     | Progress: 0/10
# [ 483.2s] Status: in_progress     | Progress: 0/10
# [ 493.6s] Status: in_progress     | Progress: 0/10
# [ 504.3s] Status: in_progress     | Progress: 0/10
# [ 514.7s] Status: in_progress     | Progress: 0/10
# [ 525.2s] Status: in_progress     | Progress: 0/10
# [ 535.8s] Status: in_progress     | Progress: 0/10
# [ 546.3s] Status: in_progress     | Progress: 0/10
# [ 556.7s] Status: in_progress     | Progress: 0/10
# [ 567.1s] Status: in_progress     | Progress: 0/10
# [ 577.6s] Status: in_progress     | Progress: 0/10
# [ 588.1s] Status: in_progress     | Progress: 0/10
# [ 598.6s] Status: in_progress     | Progress: 0/10
# [ 609.0s] Status: in_progress     | Progress: 0/10
# [ 619.5s] Status: in_progress     | Progress: 0/10
# [ 630.0s] Status: in_progress     | Progress: 0/10
# [ 640.5s] Status: in_progress     | Progress: 0/10
# [ 651.0s] Status: in_progress     | Progress: 0/10
# [ 661.5s] Status: in_progress     | Progress: 0/10
# [ 672.0s] Status: in_progress     | Progress: 0/10
# [ 682.6s] Status: in_progress     | Progress: 0/10
# [ 693.1s] Status: in_progress     | Progress: 0/10
# [ 703.6s] Status: in_progress     | Progress: 0/10
# [ 714.1s] Status: in_progress     | Progress: 0/10
# [ 724.5s] Status: in_progress     | Progress: 0/10
# [ 735.1s] Status: in_progress     | Progress: 0/10
# [ 745.5s] Status: in_progress     | Progress: 0/10
# [ 756.0s] Status: in_progress     | Progress: 0/10
# [ 766.5s] Status: in_progress     | Progress: 0/10
# [ 777.1s] Status: in_progress     | Progress: 0/10
# [ 787.6s] Status: in_progress     | Progress: 0/10
# [ 798.0s] Status: in_progress     | Progress: 0/10
# [ 808.5s] Status: in_progress     | Progress: 0/10
# [ 819.0s] Status: in_progress     | Progress: 0/10
# [ 829.7s] Status: in_progress     | Progress: 0/10
# [ 840.2s] Status: in_progress     | Progress: 0/10
# [ 850.7s] Status: in_progress     | Progress: 0/10
# [ 861.2s] Status: in_progress     | Progress: 0/10
# [ 871.7s] Status: in_progress     | Progress: 0/10
# [ 882.2s] Status: in_progress     | Progress: 0/10
# [ 892.7s] Status: in_progress     | Progress: 0/10
# [ 903.2s] Status: in_progress     | Progress: 0/10
# [ 913.6s] Status: in_progress     | Progress: 0/10
# [ 924.3s] Status: in_progress     | Progress: 0/10
# [ 934.8s] Status: in_progress     | Progress: 0/10
# [ 945.3s] Status: in_progress     | Progress: 0/10
# [ 955.7s] Status: in_progress     | Progress: 0/10
# [ 966.1s] Status: in_progress     | Progress: 0/10
# [ 976.6s] Status: in_progress     | Progress: 0/10
# [ 987.1s] Status: in_progress     | Progress: 0/10
# [ 997.5s] Status: in_progress     | Progress: 0/10
# [1008.0s] Status: in_progress     | Progress: 0/10
# [1018.5s] Status: in_progress     | Progress: 0/10
# [1029.1s] Status: in_progress     | Progress: 0/10
# [1039.6s] Status: in_progress     | Progress: 0/10
# [1050.0s] Status: in_progress     | Progress: 0/10
# [1060.6s] Status: in_progress     | Progress: 0/10
# [1071.1s] Status: in_progress     | Progress: 0/10
# [1081.6s] Status: in_progress     | Progress: 0/10
# [1092.0s] Status: in_progress     | Progress: 0/10
# [1102.5s] Status: in_progress     | Progress: 0/10
# [1112.9s] Status: in_progress     | Progress: 0/10
# [1123.4s] Status: in_progress     | Progress: 0/10
# [1133.9s] Status: in_progress     | Progress: 0/10
# [1144.4s] Status: in_progress     | Progress: 0/10
# [1155.0s] Status: in_progress     | Progress: 0/10
# [1165.5s] Status: in_progress     | Progress: 0/10
# [1175.9s] Status: in_progress     | Progress: 0/10
# [1186.3s] Status: in_progress     | Progress: 0/10
# [1197.2s] Status: in_progress     | Progress: 0/10
# [1207.7s] Status: in_progress     | Progress: 0/10
# [1218.4s] Status: in_progress     | Progress: 0/10
# [1229.0s] Status: in_progress     | Progress: 0/10
# [1239.5s] Status: in_progress     | Progress: 0/10
# [1249.9s] Status: in_progress     | Progress: 0/10
# [1260.3s] Status: in_progress     | Progress: 0/10
# [1270.7s] Status: in_progress     | Progress: 0/10
# [1281.3s] Status: in_progress     | Progress: 0/10
# [1291.8s] Status: in_progress     | Progress: 0/10
# [1302.3s] Status: in_progress     | Progress: 0/10
# [1312.8s] Status: in_progress     | Progress: 0/10
# [1323.3s] Status: in_progress     | Progress: 0/10
# [1334.1s] Status: in_progress     | Progress: 0/10
# [1344.6s] Status: in_progress     | Progress: 0/10
# [1355.3s] Status: in_progress     | Progress: 0/10
# [1366.3s] Status: in_progress     | Progress: 0/10
# [1376.8s] Status: in_progress     | Progress: 0/10
# [1387.3s] Status: in_progress     | Progress: 0/10
# [1397.8s] Status: in_progress     | Progress: 0/10
# [1408.2s] Status: in_progress     | Progress: 0/10
# [1418.6s] Status: in_progress     | Progress: 0/10
# [1429.2s] Status: in_progress     | Progress: 0/10
# [1439.7s] Status: in_progress     | Progress: 0/10
# [1450.1s] Status: in_progress     | Progress: 0/10
# [1460.5s] Status: in_progress     | Progress: 0/10
# [1471.1s] Status: in_progress     | Progress: 0/10
# [1481.7s] Status: in_progress     | Progress: 0/10
# [1492.1s] Status: in_progress     | Progress: 0/10
# [1502.7s] Status: in_progress     | Progress: 0/10
# [1513.2s] Status: in_progress     | Progress: 0/10
# [1523.6s] Status: in_progress     | Progress: 0/10
# [1534.1s] Status: in_progress     | Progress: 0/10
# [1544.5s] Status: in_progress     | Progress: 0/10
# [1555.0s] Status: in_progress     | Progress: 0/10
# [1565.5s] Status: in_progress     | Progress: 0/10
# [1575.9s] Status: in_progress     | Progress: 0/10
# [1586.5s] Status: in_progress     | Progress: 0/10
# [1597.0s] Status: in_progress     | Progress: 0/10
# [1607.5s] Status: in_progress     | Progress: 0/10
# [1618.1s] Status: in_progress     | Progress: 0/10
# [1628.6s] Status: in_progress     | Progress: 0/10
# [1639.2s] Status: in_progress     | Progress: 0/10
# [1649.9s] Status: in_progress     | Progress: 0/10
# [1660.4s] Status: in_progress     | Progress: 0/10
# [1671.0s] Status: in_progress     | Progress: 0/10
# [1681.5s] Status: in_progress     | Progress: 0/10
# [1692.0s] Status: in_progress     | Progress: 0/10
# [1702.5s] Status: in_progress     | Progress: 0/10
# [1713.0s] Status: in_progress     | Progress: 0/10
# [1723.5s] Status: in_progress     | Progress: 0/10
# [1734.0s] Status: in_progress     | Progress: 0/10
# [1744.6s] Status: in_progress     | Progress: 0/10
# [1755.3s] Status: in_progress     | Progress: 0/10
# [1765.7s] Status: in_progress     | Progress: 0/10
# [1776.2s] Status: in_progress     | Progress: 0/10
# [1786.6s] Status: in_progress     | Progress: 0/10
# [1797.3s] Status: in_progress     | Progress: 0/10
# [1807.6s] Status: in_progress     | Progress: 0/10
# [1818.1s] Status: in_progress     | Progress: 0/10
# [1828.6s] Status: in_progress     | Progress: 0/10
# [1839.1s] Status: in_progress     | Progress: 0/10
# [1849.5s] Status: in_progress     | Progress: 0/10
# [1860.2s] Status: in_progress     | Progress: 0/10
# [1870.6s] Status: in_progress     | Progress: 0/10
# [1881.0s] Status: in_progress     | Progress: 0/10
# [1891.6s] Status: in_progress     | Progress: 0/10
# [1902.2s] Status: in_progress     | Progress: 0/10
# [1912.6s] Status: in_progress     | Progress: 0/10
# [1923.1s] Status: in_progress     | Progress: 0/10
# [1933.7s] Status: in_progress     | Progress: 0/10
# [1944.2s] Status: in_progress     | Progress: 0/10
# [1954.9s] Status: in_progress     | Progress: 0/10
# [1965.4s] Status: in_progress     | Progress: 0/10
# [1976.0s] Status: in_progress     | Progress: 0/10
# [1986.6s] Status: in_progress     | Progress: 0/10
# [1997.2s] Status: in_progress     | Progress: 0/10
# [2007.9s] Status: in_progress     | Progress: 0/10
# [2018.3s] Status: in_progress     | Progress: 0/10
# [2028.8s] Status: in_progress     | Progress: 0/10
# [2039.3s] Status: in_progress     | Progress: 0/10
# [2050.0s] Status: in_progress     | Progress: 0/10
# [2060.5s] Status: in_progress     | Progress: 0/10
# [2071.0s] Status: in_progress     | Progress: 0/10
# [2081.4s] Status: in_progress     | Progress: 0/10
# [2091.8s] Status: in_progress     | Progress: 0/10
# [2102.6s] Status: in_progress     | Progress: 0/10
# [2113.4s] Status: in_progress     | Progress: 0/10
# [2123.9s] Status: in_progress     | Progress: 0/10
# [2134.5s] Status: in_progress     | Progress: 0/10
# [2144.9s] Status: in_progress     | Progress: 0/10
# [2155.3s] Status: in_progress     | Progress: 0/10
# [2165.7s] Status: in_progress     | Progress: 0/10
# [2176.2s] Status: in_progress     | Progress: 0/10
# [2186.6s] Status: in_progress     | Progress: 0/10
# [2197.2s] Status: in_progress     | Progress: 0/10
# [2207.8s] Status: in_progress     | Progress: 0/10
# [2218.3s] Status: in_progress     | Progress: 0/10
# [2228.9s] Status: in_progress     | Progress: 0/10
# [2239.2s] Status: in_progress     | Progress: 0/10
# [2249.8s] Status: in_progress     | Progress: 0/10
# [2260.2s] Status: in_progress     | Progress: 0/10
# [2270.7s] Status: in_progress     | Progress: 0/10
# [2281.2s] Status: in_progress     | Progress: 0/10
# [2291.8s] Status: in_progress     | Progress: 0/10
# [2302.2s] Status: in_progress     | Progress: 0/10
# [2312.8s] Status: in_progress     | Progress: 0/10
# [2323.3s] Status: in_progress     | Progress: 0/10
# [2334.1s] Status: in_progress     | Progress: 0/10
# [2344.6s] Status: in_progress     | Progress: 0/10
# [2355.0s] Status: in_progress     | Progress: 0/10
# [2365.4s] Status: in_progress     | Progress: 0/10
# [2375.9s] Status: in_progress     | Progress: 0/10
# [2386.6s] Status: in_progress     | Progress: 0/10
# [2397.1s] Status: in_progress     | Progress: 0/10
# [2407.6s] Status: in_progress     | Progress: 0/10
# [2418.1s] Status: in_progress     | Progress: 0/10
# [2428.5s] Status: in_progress     | Progress: 0/10
# [2438.9s] Status: in_progress     | Progress: 0/10
# [2449.3s] Status: in_progress     | Progress: 0/10
# [2460.0s] Status: in_progress     | Progress: 0/10
# [2470.5s] Status: in_progress     | Progress: 0/10
# [2480.9s] Status: in_progress     | Progress: 0/10
# [2491.3s] Status: in_progress     | Progress: 0/10
# [2501.9s] Status: in_progress     | Progress: 0/10
# [2512.4s] Status: in_progress     | Progress: 0/10
# [2522.9s] Status: in_progress     | Progress: 0/10
# [2533.4s] Status: in_progress     | Progress: 0/10
# [2543.9s] Status: in_progress     | Progress: 0/10
# [2554.2s] Status: in_progress     | Progress: 0/10
# [2564.8s] Status: in_progress     | Progress: 0/10
# [2575.2s] Status: in_progress     | Progress: 0/10
# [2585.7s] Status: in_progress     | Progress: 0/10
# [2596.7s] Status: in_progress     | Progress: 0/10
# [2607.3s] Status: in_progress     | Progress: 0/10
# [2617.8s] Status: in_progress     | Progress: 0/10
# [2628.3s] Status: in_progress     | Progress: 0/10
# [2638.9s] Status: in_progress     | Progress: 0/10
# [2649.3s] Status: in_progress     | Progress: 0/10
# [2660.1s] Status: in_progress     | Progress: 0/10
# [2670.6s] Status: in_progress     | Progress: 0/10
# [2681.1s] Status: in_progress     | Progress: 0/10
# [2692.1s] Status: in_progress     | Progress: 0/10
# [2702.7s] Status: in_progress     | Progress: 0/10
# [2713.3s] Status: in_progress     | Progress: 0/10
# [2723.9s] Status: in_progress     | Progress: 0/10
# [2734.4s] Status: in_progress     | Progress: 0/10
# [2744.9s] Status: in_progress     | Progress: 0/10
# [2755.3s] Status: in_progress     | Progress: 0/10
# [2765.8s] Status: in_progress     | Progress: 0/10
# [2776.3s] Status: in_progress     | Progress: 0/10
# [2786.9s] Status: in_progress     | Progress: 0/10
# [2797.5s] Status: in_progress     | Progress: 0/10
# [2808.1s] Status: in_progress     | Progress: 0/10
# [2818.7s] Status: in_progress     | Progress: 0/10
# [2829.1s] Status: in_progress     | Progress: 0/10
# [2839.6s] Status: in_progress     | Progress: 0/10
# [2850.0s] Status: in_progress     | Progress: 0/10
# [2860.7s] Status: in_progress     | Progress: 0/10
# [2871.2s] Status: in_progress     | Progress: 0/10
# [2881.8s] Status: in_progress     | Progress: 0/10
# [2892.3s] Status: in_progress     | Progress: 0/10
# [2902.8s] Status: in_progress     | Progress: 0/10
# [2913.3s] Status: in_progress     | Progress: 0/10
# [2924.0s] Status: in_progress     | Progress: 0/10
# [2934.6s] Status: in_progress     | Progress: 0/10
# [2944.9s] Status: in_progress     | Progress: 0/10
# [2955.5s] Status: in_progress     | Progress: 0/10
# [2966.1s] Status: in_progress     | Progress: 0/10
# [2976.6s] Status: in_progress     | Progress: 0/10
# [2987.2s] Status: in_progress     | Progress: 0/10
# [2997.7s] Status: in_progress     | Progress: 0/10
# [3008.2s] Status: in_progress     | Progress: 0/10
# [3018.7s] Status: in_progress     | Progress: 0/10
# [3029.4s] Status: in_progress     | Progress: 0/10
# [3039.8s] Status: in_progress     | Progress: 0/10
# [3050.3s] Status: in_progress     | Progress: 0/10
# [3060.8s] Status: in_progress     | Progress: 0/10
# [3071.2s] Status: in_progress     | Progress: 0/10
# [3081.6s] Status: in_progress     | Progress: 0/10
# [3092.1s] Status: in_progress     | Progress: 0/10
# [3102.6s] Status: in_progress     | Progress: 0/10
# [3113.1s] Status: in_progress     | Progress: 0/10
# [3123.6s] Status: in_progress     | Progress: 0/10
# [3134.2s] Status: in_progress     | Progress: 0/10
# [3144.6s] Status: in_progress     | Progress: 0/10
# [3155.2s] Status: in_progress     | Progress: 0/10
# [3165.6s] Status: in_progress     | Progress: 0/10
# [3176.2s] Status: in_progress     | Progress: 0/10
# [3186.5s] Status: in_progress     | Progress: 0/10
# [3197.0s] Status: in_progress     | Progress: 0/10
# [3207.4s] Status: in_progress     | Progress: 0/10
# [3218.0s] Status: in_progress     | Progress: 0/10
# [3228.4s] Status: in_progress     | Progress: 0/10
# [3239.1s] Status: in_progress     | Progress: 0/10
# [3249.6s] Status: in_progress     | Progress: 0/10
# [3260.3s] Status: in_progress     | Progress: 0/10
# [3271.0s] Status: in_progress     | Progress: 0/10
# [3281.5s] Status: in_progress     | Progress: 0/10
# [3291.8s] Status: in_progress     | Progress: 0/10
# [3302.5s] Status: in_progress     | Progress: 0/10
# [3312.9s] Status: in_progress     | Progress: 0/10
# [3324.3s] Status: in_progress     | Progress: 0/10
# [3334.8s] Status: in_progress     | Progress: 0/10
# [3345.3s] Status: in_progress     | Progress: 0/10
# [3355.8s] Status: in_progress     | Progress: 0/10
# [3366.2s] Status: in_progress     | Progress: 0/10
# [3376.7s] Status: in_progress     | Progress: 0/10
# [3387.2s] Status: in_progress     | Progress: 0/10
# [3397.7s] Status: in_progress     | Progress: 0/10
# [3408.2s] Status: in_progress     | Progress: 0/10
# [3418.6s] Status: in_progress     | Progress: 0/10
# [3429.3s] Status: in_progress     | Progress: 0/10
# [3439.8s] Status: in_progress     | Progress: 0/10
# [3450.2s] Status: in_progress     | Progress: 0/10
# [3460.6s] Status: in_progress     | Progress: 0/10
# [3471.1s] Status: in_progress     | Progress: 0/10
# [3481.7s] Status: in_progress     | Progress: 0/10
# [3492.1s] Status: in_progress     | Progress: 0/10
# [3502.6s] Status: in_progress     | Progress: 0/10
# [3513.1s] Status: in_progress     | Progress: 0/10
# [3523.7s] Status: in_progress     | Progress: 0/10
# [3534.1s] Status: in_progress     | Progress: 0/10
# [3544.5s] Status: in_progress     | Progress: 0/10
# [3555.0s] Status: in_progress     | Progress: 0/10
# [3565.5s] Status: in_progress     | Progress: 0/10
# [3575.9s] Status: in_progress     | Progress: 0/10
# [3586.6s] Status: in_progress     | Progress: 0/10
# [3597.0s] Status: in_progress     | Progress: 0/10
# [3607.6s] Status: in_progress     | Progress: 0/10
# [3618.0s] Status: in_progress     | Progress: 0/10
# [3628.6s] Status: in_progress     | Progress: 0/10
# [3638.9s] Status: in_progress     | Progress: 0/10
# [3649.4s] Status: in_progress     | Progress: 0/10
# [3659.9s] Status: in_progress     | Progress: 0/10
# [3670.3s] Status: in_progress     | Progress: 0/10
# [3680.8s] Status: in_progress     | Progress: 0/10
# [3691.3s] Status: in_progress     | Progress: 0/10
# [3701.8s] Status: in_progress     | Progress: 0/10
# [3712.2s] Status: in_progress     | Progress: 0/10
# [3723.4s] Status: in_progress     | Progress: 0/10
# [3733.9s] Status: in_progress     | Progress: 0/10
# [3744.3s] Status: in_progress     | Progress: 0/10
# [3754.8s] Status: in_progress     | Progress: 0/10
# [3765.3s] Status: in_progress     | Progress: 0/10
# [3775.7s] Status: in_progress     | Progress: 0/10
# [3786.2s] Status: in_progress     | Progress: 0/10
# [3796.8s] Status: in_progress     | Progress: 0/10
# [3807.2s] Status: in_progress     | Progress: 0/10
# [3817.7s] Status: in_progress     | Progress: 0/10
# [3828.2s] Status: in_progress     | Progress: 0/10
# [3838.8s] Status: in_progress     | Progress: 0/10
# [3849.2s] Status: in_progress     | Progress: 0/10
# [3859.6s] Status: in_progress     | Progress: 0/10
# [3870.0s] Status: in_progress     | Progress: 0/10
# [3880.5s] Status: in_progress     | Progress: 0/10
# [3890.9s] Status: in_progress     | Progress: 0/10
# [3901.6s] Status: in_progress     | Progress: 0/10
# [3912.1s] Status: in_progress     | Progress: 0/10
# [3923.0s] Status: in_progress     | Progress: 0/10
# [3933.4s] Status: in_progress     | Progress: 0/10
# [3943.9s] Status: in_progress     | Progress: 0/10
# [3954.4s] Status: in_progress     | Progress: 0/10
# [3964.9s] Status: in_progress     | Progress: 0/10
# [3975.3s] Status: in_progress     | Progress: 0/10
# [3985.8s] Status: in_progress     | Progress: 0/10
# [3996.5s] Status: in_progress     | Progress: 0/10
# [4007.0s] Status: in_progress     | Progress: 0/10
# [4017.4s] Status: in_progress     | Progress: 0/10
# [4027.9s] Status: in_progress     | Progress: 0/10
# [4038.4s] Status: in_progress     | Progress: 0/10
# [4048.9s] Status: in_progress     | Progress: 0/10
# [4059.5s] Status: in_progress     | Progress: 0/10
# [4069.9s] Status: in_progress     | Progress: 0/10
# [4080.3s] Status: in_progress     | Progress: 0/10
# [4090.7s] Status: in_progress     | Progress: 0/10
# [4101.2s] Status: in_progress     | Progress: 0/10
# [4111.6s] Status: in_progress     | Progress: 0/10
# [4122.3s] Status: in_progress     | Progress: 0/10
# [4132.7s] Status: in_progress     | Progress: 0/10
# [4143.1s] Status: in_progress     | Progress: 0/10
# [4153.8s] Status: in_progress     | Progress: 0/10
# [4164.2s] Status: in_progress     | Progress: 0/10
# [4174.6s] Status: in_progress     | Progress: 0/10
# [4185.1s] Status: in_progress     | Progress: 0/10
# [4195.6s] Status: in_progress     | Progress: 0/10
# [4206.0s] Status: in_progress     | Progress: 0/10
# [4216.5s] Status: in_progress     | Progress: 0/10
# [4227.0s] Status: in_progress     | Progress: 0/10
# [4237.6s] Status: in_progress     | Progress: 0/10
# [4248.1s] Status: in_progress     | Progress: 0/10
# [4258.5s] Status: in_progress     | Progress: 0/10
# [4268.9s] Status: in_progress     | Progress: 0/10
# [4279.6s] Status: in_progress     | Progress: 0/10
# [4290.0s] Status: in_progress     | Progress: 0/10
# [4301.1s] Status: in_progress     | Progress: 0/10
# [4311.5s] Status: in_progress     | Progress: 0/10
# [4321.9s] Status: in_progress     | Progress: 0/10
# [4332.4s] Status: in_progress     | Progress: 0/10
# [4342.9s] Status: in_progress     | Progress: 0/10
# [4353.4s] Status: in_progress     | Progress: 0/10
# [4364.0s] Status: in_progress     | Progress: 0/10
# [4374.6s] Status: in_progress     | Progress: 0/10
# [4385.0s] Status: in_progress     | Progress: 0/10
# [4395.5s] Status: in_progress     | Progress: 0/10
# [4406.1s] Status: in_progress     | Progress: 0/10
# [4416.5s] Status: in_progress     | Progress: 0/10
# [4426.9s] Status: in_progress     | Progress: 0/10
# [4437.4s] Status: in_progress     | Progress: 0/10
# [4448.0s] Status: in_progress     | Progress: 0/10
# [4458.4s] Status: in_progress     | Progress: 0/10
# [4468.8s] Status: in_progress     | Progress: 0/10
# [4479.2s] Status: in_progress     | Progress: 0/10
# [4489.8s] Status: in_progress     | Progress: 0/10
# [4500.3s] Status: in_progress     | Progress: 0/10
# [4510.8s] Status: in_progress     | Progress: 0/10
# [4521.7s] Status: in_progress     | Progress: 0/10
# [4532.1s] Status: in_progress     | Progress: 0/10
# [4542.6s] Status: in_progress     | Progress: 0/10
# [4553.1s] Status: in_progress     | Progress: 0/10
# [4563.7s] Status: in_progress     | Progress: 0/10
# [4574.1s] Status: in_progress     | Progress: 0/10
# [4584.5s] Status: in_progress     | Progress: 0/10
# [4595.0s] Status: in_progress     | Progress: 0/10
# [4605.7s] Status: in_progress     | Progress: 0/10
# [4616.1s] Status: in_progress     | Progress: 0/10
# [4626.5s] Status: in_progress     | Progress: 0/10
# [4637.1s] Status: in_progress     | Progress: 0/10
# [4647.6s] Status: in_progress     | Progress: 0/10
# [4658.0s] Status: in_progress     | Progress: 0/10
# [4668.5s] Status: in_progress     | Progress: 0/10
# [4678.9s] Status: in_progress     | Progress: 0/10
# [4689.4s] Status: in_progress     | Progress: 0/10
# [4699.9s] Status: in_progress     | Progress: 0/10
# [4710.4s] Status: in_progress     | Progress: 0/10
# [4720.8s] Status: in_progress     | Progress: 0/10
# [4731.3s] Status: in_progress     | Progress: 0/10
# [4742.0s] Status: in_progress     | Progress: 0/10
# [4752.4s] Status: in_progress     | Progress: 0/10
# [4762.9s] Status: in_progress     | Progress: 0/10
# [4773.5s] Status: in_progress     | Progress: 0/10
# [4783.9s] Status: in_progress     | Progress: 0/10
# [4794.3s] Status: in_progress     | Progress: 0/10
# [4805.3s] Status: in_progress     | Progress: 0/10
# [4815.8s] Status: in_progress     | Progress: 0/10
# [4826.3s] Status: in_progress     | Progress: 0/10
# [4836.8s] Status: in_progress     | Progress: 0/10
# [4847.2s] Status: in_progress     | Progress: 0/10
# [4857.9s] Status: in_progress     | Progress: 0/10
# [4868.4s] Status: in_progress     | Progress: 0/10
# [4879.0s] Status: in_progress     | Progress: 0/10
# [4889.5s] Status: in_progress     | Progress: 0/10
# [4900.1s] Status: in_progress     | Progress: 0/10
# [4910.6s] Status: in_progress     | Progress: 0/10
# [4921.3s] Status: in_progress     | Progress: 0/10
# [4931.8s] Status: in_progress     | Progress: 0/10
# [4942.3s] Status: in_progress     | Progress: 0/10
# [4952.8s] Status: in_progress     | Progress: 0/10
# [4963.3s] Status: in_progress     | Progress: 0/10
# [4973.9s] Status: in_progress     | Progress: 0/10
# [4984.2s] Status: in_progress     | Progress: 0/10
# [4994.7s] Status: in_progress     | Progress: 0/10
# [5005.1s] Status: in_progress     | Progress: 0/10
# [5015.7s] Status: in_progress     | Progress: 0/10
# [5026.3s] Status: in_progress     | Progress: 0/10
# [5036.8s] Status: in_progress     | Progress: 0/10
# [5047.3s] Status: in_progress     | Progress: 0/10
# [5057.8s] Status: in_progress     | Progress: 0/10
# [5068.3s] Status: in_progress     | Progress: 0/10
# [5078.8s] Status: in_progress     | Progress: 0/10
# [5089.4s] Status: in_progress     | Progress: 0/10
# [5100.1s] Status: in_progress     | Progress: 0/10
# [5110.6s] Status: in_progress     | Progress: 0/10
# [5121.1s] Status: in_progress     | Progress: 0/10
# [5131.5s] Status: in_progress     | Progress: 0/10
# [5142.1s] Status: in_progress     | Progress: 0/10
# [5152.5s] Status: in_progress     | Progress: 0/10
# [5162.9s] Status: in_progress     | Progress: 0/10
# [5173.4s] Status: in_progress     | Progress: 0/10
# [5183.8s] Status: in_progress     | Progress: 0/10
# [5194.3s] Status: in_progress     | Progress: 0/10
# [5205.0s] Status: in_progress     | Progress: 0/10
# [5215.4s] Status: in_progress     | Progress: 0/10
# [5226.0s] Status: in_progress     | Progress: 0/10
# [5236.4s] Status: in_progress     | Progress: 0/10
# [5247.0s] Status: in_progress     | Progress: 0/10
# [5257.4s] Status: in_progress     | Progress: 0/10
# [5267.8s] Status: in_progress     | Progress: 0/10
# [5278.2s] Status: in_progress     | Progress: 0/10
# [5288.7s] Status: in_progress     | Progress: 0/10
# [5299.1s] Status: in_progress     | Progress: 0/10
# [5309.8s] Status: in_progress     | Progress: 0/10
# [5320.2s] Status: in_progress     | Progress: 0/10
# [5330.6s] Status: in_progress     | Progress: 0/10
# [5341.3s] Status: in_progress     | Progress: 0/10
# [5351.9s] Status: in_progress     | Progress: 0/10
# [5362.4s] Status: in_progress     | Progress: 0/10
# [5372.9s] Status: in_progress     | Progress: 0/10
# [5384.1s] Status: in_progress     | Progress: 0/10
# [5394.6s] Status: in_progress     | Progress: 0/10
# [5405.1s] Status: in_progress     | Progress: 0/10
# [5415.5s] Status: in_progress     | Progress: 0/10
# [5426.0s] Status: in_progress     | Progress: 0/10
# [5436.5s] Status: in_progress     | Progress: 0/10
# [5447.0s] Status: in_progress     | Progress: 0/10
# [5457.7s] Status: in_progress     | Progress: 0/10
# [5468.1s] Status: in_progress     | Progress: 0/10
# [5478.6s] Status: in_progress     | Progress: 0/10
# [5489.2s] Status: in_progress     | Progress: 0/10
# [5499.6s] Status: in_progress     | Progress: 0/10
# [5510.2s] Status: in_progress     | Progress: 0/10
# [5520.8s] Status: in_progress     | Progress: 0/10
# [5531.2s] Status: in_progress     | Progress: 0/10
# [5541.8s] Status: in_progress     | Progress: 0/10
# [5552.2s] Status: in_progress     | Progress: 0/10
# [5562.7s] Status: in_progress     | Progress: 0/10
# [5573.2s] Status: in_progress     | Progress: 0/10
# [5583.8s] Status: in_progress     | Progress: 0/10
# [5594.3s] Status: in_progress     | Progress: 0/10
# [5605.0s] Status: in_progress     | Progress: 0/10
# [5615.5s] Status: in_progress     | Progress: 0/10
# [5626.0s] Status: in_progress     | Progress: 0/10
# [5636.5s] Status: in_progress     | Progress: 0/10
# [5647.0s] Status: in_progress     | Progress: 0/10
# [5657.4s] Status: in_progress     | Progress: 0/10
# [5667.8s] Status: in_progress     | Progress: 0/10
# [5678.4s] Status: in_progress     | Progress: 0/10
# [5688.9s] Status: in_progress     | Progress: 0/10
# [5699.4s] Status: in_progress     | Progress: 0/10
# [5709.9s] Status: in_progress     | Progress: 0/10
# [5720.5s] Status: in_progress     | Progress: 0/10
# [5730.9s] Status: in_progress     | Progress: 0/10
# [5741.3s] Status: in_progress     | Progress: 0/10
# [5751.9s] Status: in_progress     | Progress: 0/10
# [5762.5s] Status: in_progress     | Progress: 0/10
# [5773.1s] Status: in_progress     | Progress: 0/10
# [5783.6s] Status: in_progress     | Progress: 0/10
# [5794.1s] Status: in_progress     | Progress: 0/10
# [5804.6s] Status: in_progress     | Progress: 0/10
# [5815.1s] Status: in_progress     | Progress: 0/10
# [5825.6s] Status: in_progress     | Progress: 0/10
# [5836.2s] Status: in_progress     | Progress: 0/10
# [5846.6s] Status: in_progress     | Progress: 0/10
# [5857.0s] Status: in_progress     | Progress: 0/10
# [5867.5s] Status: in_progress     | Progress: 0/10
# [5878.0s] Status: in_progress     | Progress: 0/10
# [5888.7s] Status: in_progress     | Progress: 0/10
# [5899.2s] Status: in_progress     | Progress: 0/10
# [5909.6s] Status: in_progress     | Progress: 0/10
# [5920.1s] Status: in_progress     | Progress: 0/10
# [5930.6s] Status: in_progress     | Progress: 0/10
# [5941.0s] Status: in_progress     | Progress: 0/10
# [5952.1s] Status: in_progress     | Progress: 0/10
# [5962.6s] Status: in_progress     | Progress: 0/10
# [5973.2s] Status: in_progress     | Progress: 0/10
# [5983.7s] Status: in_progress     | Progress: 0/10
# [5994.4s] Status: in_progress     | Progress: 0/10
# [6005.0s] Status: in_progress     | Progress: 0/10
# [6015.5s] Status: in_progress     | Progress: 0/10
# [6026.1s] Status: in_progress     | Progress: 0/10
# [6036.5s] Status: in_progress     | Progress: 0/10
# [6046.9s] Status: in_progress     | Progress: 0/10
# [6057.3s] Status: in_progress     | Progress: 0/10
# [6067.8s] Status: in_progress     | Progress: 0/10
# [6078.3s] Status: in_progress     | Progress: 0/10
# [6088.8s] Status: in_progress     | Progress: 0/10
# [6099.2s] Status: in_progress     | Progress: 0/10
# [6109.9s] Status: in_progress     | Progress: 0/10
# [6120.3s] Status: in_progress     | Progress: 0/10
# [6130.7s] Status: in_progress     | Progress: 0/10
# [6141.4s] Status: in_progress     | Progress: 0/10
# [6151.9s] Status: in_progress     | Progress: 0/10
# [6162.4s] Status: in_progress     | Progress: 0/10
# [6173.0s] Status: in_progress     | Progress: 0/10
# [6183.6s] Status: in_progress     | Progress: 0/10
# [6194.3s] Status: in_progress     | Progress: 0/10
# [6204.8s] Status: in_progress     | Progress: 0/10
# [6215.3s] Status: in_progress     | Progress: 0/10
# [6225.7s] Status: in_progress     | Progress: 2/10
# [6236.1s] Status: in_progress     | Progress: 3/10
# [6246.7s] Status: in_progress     | Progress: 3/10
# [6257.3s] Status: in_progress     | Progress: 7/10
# [6267.8s] Status: in_progress     | Progress: 7/10
# [6278.3s] Status: in_progress     | Progress: 7/10
# [6288.9s] Status: in_progress     | Progress: 7/10
# [6299.4s] Status: in_progress     | Progress: 7/10
# [6310.0s] Status: completed       | Progress: 10/10
#
# ✅ Batch finished in 6310.0s with status: completed
#    Completed: 10 | Failed: 0

# %%
job = client.batches.retrieve('batch_6aa03405a098819099d45bd670f11454')

# %%
if job.status == "completed" and job.output_file_id:
    # Download the output file
    output_content = client.files.content(job.output_file_id)
    output_text = output_content.text
    
    # Save locally
    with open("batch_output.jsonl", "w") as f:
        f.write(output_text)
    
    # Parse each line
    batch_results = []
    for line in output_text.strip().split("\n"):
        result = json.loads(line)
        batch_results.append(result)
    
    print(f"Downloaded {len(batch_results)} results")
else:
    print(f"Batch did not complete successfully. Status: {job.status}")
    if job.error_file_id:
        error_content = client.files.content(job.error_file_id)
        print("Errors:", error_content.text[:500])
# Out:
# Downloaded 10 results

# %%
# Examine one result in detail
if batch_results:
    sample = batch_results[0]
    print(f"Custom ID: {sample['custom_id']}")
    print(f"Status code: {sample['response']['status_code']}")
    
    # The response body contains the same structure as a Responses API call
    body = sample['response']['body']
    
    # Extract the output text from the response
    output_items = body.get('output', [])
    for item in output_items:
        if item.get('type') == 'message':
            for content in item.get('content', []):
                if content.get('type') == 'output_text':
                    print(f"\nOutput text (first 300 chars):\n{content['text'][:300]}...")
    
    # Check usage
    usage = body.get('usage', {})
    print(f"\nUsage: input={usage.get('input_tokens', 'N/A')}, output={usage.get('output_tokens', 'N/A')}")
    print(f"Cached: {usage.get('input_tokens_details', {}).get('cached_tokens', 'N/A')}")
# Out:
# Custom ID: product-P001
# Status code: 200
#
# Output text (first 300 chars):
# {
#   "seo_summary": "Experience immersive, distraction-free listening with these over-ear wireless headphones featuring active noise cancellation and a 30-hour battery life for all-day comfort. Enjoy seamless device switching with Bluetooth 5.3 and multipoint connectivity, and a foldable design for t...
#
# Usage: input=1249, output=2212
# Cached: 1152

# %% [markdown]
# :mortar_board: A little throwback to college days, but with a lot more learning! :eyes:
#
# The IIT Roorkee Campus Immersion 2026 is shaping up to be a mix of everything that makes campus life special — learning, building, collaborating, meeting people, and of course, having some fun along the way! :sparkles:
#
# We’re curating this experience to give you a chance to step away from the screen and experience learning in a whole new way:
# :bulb: Learn & build through hands-on experiences and real-world challenges
# :handshake: Collaborate & connect with fellow learners
# :male-teacher: Interact with IIT Roorkee professors and Scaler faculty
# :zap: Take on hackathons and exciting challenges
# :school_satchel: Get those college-day feels — campus life, conversations, new friendships and memories
# :partying_face: And most importantly, learn, collaborate and have a great time while doing it!
#
# There’s a lot being planned, and we’re excited to bring together fun and learning under one roof — or rather, one campus! :wink:
#
# We’d love to know who’s excited to be a part of this experience.
#
# :point_right: Share your interest here:
# https://docs.google.com/forms/d/e/1FAIpQLSd5yPquq1J0XYPo1ppGK6OAK6hAK8f1M-HaC9IxTroOligPBg/viewform?usp=sharing&ouid=113200008645481478431
#
# :round_pushpin: IIT Roorkee Campus
# :date: 13th–15th November 2026
#
# Few days of learning, collaboration, new experiences and a little college nostalgia. :heart:
#
# Ready to experience IIT Roorkee beyond the classroom? :rocket:
